# %%
from datetime import datetime
from pandas import read_table, DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


obs = pd.read_csv('Datos_Valparaiso.txt',delimiter="\t")

# %%
obs.head()
# Out:
#             Time (UTC)  prs(m)  rad(m)
# 0  2019-09-01 00:00:28   2.015   3.319
# 1  2019-09-01 00:01:28   2.020   3.321
# 2  2019-09-01 00:02:29   2.080   3.332
# 3  2019-09-01 00:03:28   1.971   3.347
# 4  2019-09-01 00:04:28   2.005   3.335

# %% [markdown]
# ## Codigo para cambiar estilo de fecha columnas separadas.

# %%
dtime = []
for i in range (len(obs)):
    year = obs['year'][i]
    month = obs['month'][i]
    day = obs['day'][i]
    hour = obs['hour'][i]
    minu = obs['min'][i]
    dt = datetime(year, month,day, hour,minu)
    dt = pd.to_datetime(dt)
    dtime.append(dt)
    
obs['datetime']=dtime

# %% [markdown]
# ## Convertir fecha a formato datetime

# %%
obs['datetime']= pd.to_datetime(obs["Time (UTC)"])
indexobs = obs["datetime"]
elev = list(obs["prs(m)"])
obs = pd.DataFrame(data = {'elev':elev}, index= indexobs)

# %%
obs
# Out:
#                       elev
# datetime
# 2019-09-01 00:00:28  2.015
# 2019-09-01 00:01:28  2.020
# 2019-09-01 00:02:29  2.080
# 2019-09-01 00:03:28  1.971
# 2019-09-01 00:04:28  2.005
# ...                    ...
# 2019-09-30 23:55:27  2.016
# 2019-09-30 23:56:27  1.918
# 2019-09-30 23:57:27  2.095
# 2019-09-30 23:58:28  1.978
# 2019-09-30 23:59:27  2.011
#
# [42677 rows x 1 columns]

# %% [markdown]
# ## Se seleccionara el mes de octubre de los registros para ser usados por ttide.

# %%
#obs = obs['2018-10']

# %% [markdown]
# promedios horarios

# %%
obs = obs.resample('H').mean()

# %%
fig, ax = plt.subplots(figsize=(16, 6))
ax.plot(obs.index[0:180], obs['elev'][0:180], alpha=0.5)
plt.xticks(rotation='vertical')
# Out:
# (array([737303., 737304., 737305., 737306., 737307., 737308., 737309.,
#         737310.]), <a list of 8 Text xticklabel objects>)

# %%
obs.describe()
# Out:
#              elev
# count  720.000000
# mean     2.261882
# std      0.377680
# min      1.421417
# 25%      1.966860
# 50%      2.235233
# 75%      2.559621
# max      3.194150

# %%
dti = pd.date_range('2019-11-28', periods=30*24+1, freq='2T')
dti = dti.tolist()
dti = np.array(dti)

dti2 = obs.index.tolist()
dti2 = np.array(dti2)

# %%
import ttide
from ttide.t_tide import t_tide

# %%
LatV = -33.02730833
out_tide_V= t_tide(obs['elev'], dt=1,stime=dti2[0] ,lat=LatV)
# Out:
# -----------------------------------
# nobs = 720
# ngood = 719
# record length (days) = 30.00
# start time: 2019-09-01 00:00:00
# rayleigh criterion = 1.0
#
# Greenwich phase computed with nodal
#                    corrections applied to amplitude
#                    and phase relative to center time
#
# x0= 2.26  xtrend= 0
# var(data)= 0.14    var(prediction)= 0.14    var(residual)= 0.00
# var(prediction)/var(data) (%) = 96.8
#
#         tidal amplitude and phase with 95 % CI estimates
#  tide      freq        amp      amp_err   pha      pha_err    snr
#   MSF   0.0028219     0.0151     0.040     85.93    145.86      0.14
#   2Q1   0.0357064     0.0031     0.005    279.51    109.63       0.4
# * Q1    0.0372185     0.0224     0.006    320.45     15.98        14
# * O1    0.0387307     0.0958     0.006    347.54      3.50   2.2e+02
# * NO1   0.0402686     0.0189     0.004    357.93     13.16        18
# * K1    0.0417807     0.1170     0.006     44.65      3.10   3.9e+02
#   J1    0.0432929     0.0059     0.006     55.49     67.28         1
#   OO1   0.0448308     0.0051     0.006    129.77     67.51      0.82
#   UPS1  0.0463430     0.0061     0.006    168.21     64.89       1.1
# * N2    0.0789992     0.1101     0.022     17.01     12.05        24
# * M2    0.0805114     0.4422     0.021     46.86      2.83   4.3e+02
# * S2    0.0833333     0.1878     0.019     70.81      6.51     1e+02
#   ETA2  0.0850736     0.0017     0.016    175.46    248.61     0.012
#   MO3   0.1192421     0.0006     0.001    150.05     94.72      0.46
# * M3    0.1207671     0.0022     0.001    254.38     30.40       4.4
#   MK3   0.1222921     0.0006     0.001    215.52     95.29      0.45
# * SK3   0.1251141     0.0022     0.001    185.92     31.27       3.3
# * MN4   0.1595106     0.0018     0.001    237.45     25.72       7.3
# * M4    0.1610228     0.0022     0.001    349.95     18.50       8.8
#   MS4   0.1638447     0.0002     0.001     28.53    175.86      0.11
#   S4    0.1666667     0.0009     0.001    147.30     48.57       1.4
#   2MK5  0.2028035     0.0003     0.001    246.34    156.45       0.2
#   2SK5  0.2084474     0.0013     0.001    184.23     52.64       1.7
#   2MN6  0.2400221     0.0005     0.001    102.22    106.78      0.47
#   M6    0.2415342     0.0003     0.001    227.37    152.89      0.18
# * 2MS6  0.2443561     0.0013     0.001    106.61     34.87       2.2
#   2SM6  0.2471781     0.0008     0.001    145.69     62.29      0.97
#   3MK7  0.2833149     0.0002     0.000    195.38    165.58      0.18
#   M8    0.3220456     0.0002     0.001    318.17    131.57      0.21
# /home/lenovio/Tarea4_maritima/ttide/t_tide.py:295: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   coef = np.linalg.lstsq(tc[gd, :], xin[gd])[0].T
# /home/lenovio/anaconda3/envs/MachineLearning/lib/python3.7/site-packages/numpy/lib/type_check.py:161: FutureWarning: `real` is deprecated and will be removed in a future version. To eliminate this warning for a Series `ser`, use `np.real(ser.to_numpy())` or `ser.to_numpy().real`.
#   return val.real
# /home/lenovio/anaconda3/envs/MachineLearning/lib/python3.7/site-packages/numpy/lib/type_check.py:204: FutureWarning: `imag` is deprecated and will be removed in a future version. To eliminate this warning for a Series `ser`, use `np.imag(ser.to_numpy())` or `ser.to_numpy().imag`.
#   return val.imag
# /home/lenovio/Tarea4_maritima/ttide/t_utils.py:447: FutureWarning: `real` is deprecated and will be removed in a future version. To eliminate this warning for a Series `ser`, use `np.real(ser.to_numpy())` or `ser.to_numpy().real`.
#   x = np.var(out['xingd'].real, ddof=1)
# /home/lenovio/Tarea4_maritima/ttide/t_utils.py:449: FutureWarning: `real` is deprecated and will be removed in a future version. To eliminate this warning for a Series `ser`, use `np.real(ser.to_numpy())` or `ser.to_numpy().real`.
#   xr = np.var(out['xresgd'].real, ddof=1)

# %%
valores = out_tide_V['tidecon']
names2 = out_tide_V['nameu']
names = ['MSF', '2Q1', 'Q1', 'O1', 'NO1', 'K1', 'J1', 'OO1',
       'UPS1', 'N2', 'M2', 'S2', 'ETA2', 'MO3', 'M3', 'MK3',
       'SK3', 'MN4', 'M4', 'MS4', 'S4', '2MK5', '2SK5', '2MN6',
       'M6', '2MS6', '2SM6', '3MK7', 'M8']
variables = ['amp','amp-err','pha','pha-err']
freq = out_tide_V['fu']
noise = out_tide_V['snr']

result_tide= pd.DataFrame(data =valores, index = names, columns = variables)
result_tide['freq']= freq
result_tide['snr']= noise

result_tide
# Out:
#            amp   amp-err         pha     pha-err      freq         snr
# MSF   0.015138  0.040441   85.927864  145.864151  0.002822    0.140122
# 2Q1   0.003086  0.004857  279.508187  109.633806  0.035706    0.403758
# Q1    0.022373  0.005911  320.448680   15.981776  0.037219   14.326826
# O1    0.095817  0.006462  347.541549    3.502654  0.038731  219.828467
# NO1   0.018878  0.004437  357.934556   13.161396  0.040269   18.102566
# K1    0.116963  0.005930   44.654412    3.095167  0.041781  389.007345
# J1    0.005886  0.005766   55.493412   67.276234  0.043293    1.041995
# OO1   0.005065  0.005592  129.773194   67.514906  0.044831    0.820461
# UPS1  0.006093  0.005775  168.206295   64.893068  0.046343    1.113073
# N2    0.110135  0.022356   17.013851   12.049153  0.078999   24.269933
# M2    0.442172  0.021436   46.855431    2.829081  0.080511  425.509651
# S2    0.187791  0.018780   70.814480    6.512099  0.083333   99.993895
# ETA2  0.001741  0.015985  175.459768  248.607153  0.085074    0.011865
# MO3   0.000619  0.000910  150.054503   94.720594  0.119242    0.462707
# M3    0.002172  0.001038  254.379313   30.399964  0.120767    4.380161
# MK3   0.000641  0.000956  215.523086   95.292249  0.122292    0.450149
# SK3   0.002176  0.001193  185.922213   31.274097  0.125114    3.330804
# MN4   0.001833  0.000678  237.449513   25.720800  0.159511    7.297536
# M4    0.002225  0.000752  349.953772   18.495824  0.161023    8.759989
# MS4   0.000187  0.000559   28.532345  175.864924  0.163845    0.112422
# S4    0.000893  0.000759  147.302996   48.565176  0.166667    1.382718
# 2MK5  0.000348  0.000775  246.339796  156.446029  0.202804    0.201635
# 2SK5  0.001312  0.001009  184.230818   52.636086  0.208447    1.689503
# 2MN6  0.000459  0.000667  102.220064  106.780913  0.240022    0.473507
# M6    0.000254  0.000597  227.366297  152.885645  0.241534    0.181087
# 2MS6  0.001299  0.000871  106.608159   34.866226  0.244356    2.221720
# 2SM6  0.000792  0.000804  145.685191   62.294741  0.247178    0.969775
# 3MK7  0.000202  0.000474  195.382929  165.582500  0.283315    0.180859
# M8    0.000232  0.000507  318.168301  131.572482  0.322046    0.208603

# %%
t = np.linspace(0,719,720)
a0 = 2.261882

# %%
M2 =  result_tide['amp']['M2']*np.cos(2*np.pi*result_tide['freq']['M2']*t-result_tide['pha']['M2'])
S2 =  result_tide['amp']['S2']*np.cos(2*np.pi*result_tide['freq']['S2']*t-result_tide['pha']['S2'])
K1 =  result_tide['amp']['K1']*np.cos(2*np.pi*result_tide['freq']['K1']*t-result_tide['pha']['K1'])
O1 =  result_tide['amp']['O1']*np.cos(2*np.pi*result_tide['freq']['O1']*t-result_tide['pha']['O1'])
N2 =  result_tide['amp']['N2']*np.cos(2*np.pi*result_tide['freq']['N2']*t-result_tide['pha']['N2'])
M3 =  result_tide['amp']['M3']*np.cos(2*np.pi*result_tide['freq']['M3']*t-result_tide['pha']['M3'])
Q1 =  result_tide['amp']['Q1']*np.cos(2*np.pi*result_tide['freq']['Q1']*t-result_tide['pha']['Q1'])
SK3 = result_tide['amp']['SK3']*np.cos(2*np.pi*result_tide['freq']['SK3']*t-result_tide['pha']['SK3'])

# %%
fig, (ax0, ax1, ax2, ax3, ax4) = plt.subplots(nrows=5, sharey=True, sharex=True, figsize=(16, 10))

ax0.plot(obs.index[0:25], M2[0:25], label=u'Principal Lunar')
ax0.legend(numpoints=1, loc='lower right')

ax1.plot(obs.index[0:25],S2[0:25], alpha=0.5, label=u'Principal Solar')
ax1.legend(numpoints=1, loc='lower right')

ax2.plot(obs.index[0:25], K1[0:25], alpha=0.5, label=u'Luni Solar Diurnal')
_ = ax2.legend(numpoints=1, loc='lower right')

ax3.plot(obs.index[0:25], (M2+S2+K1+O1*N2+M3+Q1+SK3)[0:25]+a0, alpha=0.5, label=u'Nivel medio mas componentes')
_ = ax3.legend(numpoints=1, loc='lower right')

ax4.plot(obs.index[0:25],  obs['elev'][0:25], alpha=0.5, label=u'Nivel real')
_ = ax4.legend(numpoints=1, loc='lower right')

# %% [markdown]
# ## Pronostico T_TIDE

# %%
from ttide import t_predic

# %%
t_time  = dti
names = names2
freq = freq
tidecon = valores
pred = t_predic(t_time,names,freq,tidecon)

# %%
pred2 = t_predic(dti2,names,freq,tidecon)

# %%
fig, (ax0,ax4) = plt.subplots(nrows=2, sharey=True, sharex=True, figsize=(16, 10))

ax0.plot( dti2,pred2+a0, alpha=0.5, label=u'Pronostico t_tide')
_ = ax0.legend(numpoints=1, loc='upper right')

ax4.plot(obs.index,  obs['elev'], alpha=0.5, label=u'Nivel real')
_ = ax4.legend(numpoints=1, loc='lower right')

# %%
fig, (ax0) = plt.subplots(nrows=1, sharey=True, sharex=True, figsize=(16, 10))

ax0.plot( dti,pred+a0, alpha=0.5, label=u'Pronostico mareas 28 Noviembre 2T')
_ = ax0.legend(numpoints=1, loc='upper right')
